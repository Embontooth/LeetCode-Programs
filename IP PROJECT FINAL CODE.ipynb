# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("C://Users/David/OneDrive/Documents/School/Informatics/Project/Students.csv",index_col="Roll No")
while True:
    a=int(input("""Do you want to 
    1. Analyze the data
    2. Visualise the data
    3. Exit
    """))
    if a==1:
        b=int(input(""" Would you like to select data based on:
        1. Stream
        2. Subject wise
        3. Exit
        """))
        while b:
            if b==3:
                break
            elif b==1:
                print("The Streams are: ",df.Stream.unique())
                Q=input(""" Enter which stream you would like to access 
                (type "Exit" to exit)
                """)
                if Q=="Science":
                    w=df.groupby("Stream")
                    s=w.get_group("Science")
                    n=int(input("""Which subject would you like to analyse:
                    1. Subject 1
                    2. Subject 2
                    3. Subject 3
                    4. Subject 4
                    5. Subject 5
                    """))
                    if n>5:
                        print("Invalid Input")
                        continue
                    while n:
                        m=int(input("""Do you want to analyse:
                        1. Grade wise
                        2. Mark wise
                        3. Exit
                        """))
                        if m==1:
                            print(s.groupby("Grade"+str(n))["Grade"+str(n)].count())
                        elif m==2:
                            while True: 
                                o=int(input("""Would you like to: 
                                1. Count the number of students with unique data
                                2. Minimum marks
                                3. Maximum marks
                                4. Total
                                5. Average
                                6. Exit 
                                """))   
                                if o==1:
                                    print(s.groupby("Mark"+str(n))["Mark"+str(n)].count())
                                    continue
                                elif o==2:
                                    print(s.groupby("Subject"+str(n))["Mark"+str(n)].min())
                                elif o==3:
                                    print(s.groupby("Subject"+str(n))["Mark"+str(n)].max())
                                elif o==4:
                                    print(s.groupby("Subject"+str(n))["Mark"+str(n)].sum())
                                elif o==5:
                                    print(s.groupby("Subject"+str(n))["Mark"+str(n)].mean())
                                elif o==6:
                                    break
                                else:
                                    print("Invalid input")
                        elif m==3:
                            break
                        else:
                            print("Invalid input")
                elif Q=="Commerce":
                    w=df.groupby("Stream")
                    s=w.get_group("Commerce")
                    n=int(input("""Which subject would you like to analyse:
                    1. Subject 1
                    2. Subject 2
                    3. Subject 3
                    4. Subject 4
                    5. Subject 5
                    """))
                    while n:
                        m=int(input("""Do you want to analyse:
                        1. Grade wise
                        2. Mark wise
                        3. Exit
                        """))
                        if m==1:
                            print(s.groupby("Grade"+str(n))["Grade"+str(n)].count())
                        elif m==2:
                            while True: 
                                o=int(input("""Would you like to: 
                                1. Count the number of students with unique marks
                                2. Minimum marks
                                3. Maximum marks
                                4. Total marks 
                                5. Average marks 
                                6. Exit 
                                """))   
                                if o==1:
                                    print(s.groupby("Mark"+str(n))["Mark"+str(n)].count())
                                    continue
                                elif o==2:
                                    print(s.groupby("Subject"+str(n))["Mark"+str(n)].min())
                                elif o==3:
                                    print(s.groupby("Subject"+str(n))["Mark"+str(n)].max())
                                elif o==4:
                                    print(s.groupby("Subject"+str(n))["Mark"+str(n)].sum())
                                elif o==5:
                                    print(s.groupby("Subject"+str(n))["Mark"+str(n)].mean())
                                elif o==6:
                                    break
                                else:
                                    print("Invalid input")
                        elif m==3:
                            break
                        else:
                            print("Invalid input")
                elif Q=="Humanities":
                    w=df.groupby("Stream")
                    s=w.get_group("Humanities")
                    n=int(input("""Which subject would you like to analyse:
                    1. Subject 1
                    2. Subject 2
                    3. Subject 3
                    4. Subject 4
                    5. Subject 5
                    """))
                    if n>5:
                        print("Invalid Input")
                        continue
                    while n:
                        m=int(input("""Do you want to analyse:
                        1. Grade wise
                        2. Mark wise
                        3. Exit
                        """))
                        if m==1:
                            print(s.groupby("Grade"+str(n))["Grade"+str(n)].count())
                        elif m==2:
                            while True: 
                                o=int(input("""Would you like to: 
                                1. Count the number of students with unique data
                                2. Minimum marks
                                3. Maximum marks
                                4. Total
                                5. Average
                                6. Exit 
                                """))   
                                if o==1:
                                    print(s.groupby("Mark"+str(n))["Mark"+str(n)].count())
                                    continue
                                elif o==2:
                                    print(s.groupby("Subject"+str(n))["Mark"+str(n)].min())
                                elif o==3:
                                    print(s.groupby("Subject"+str(n))["Mark"+str(n)].max())
                                elif o==4:
                                    print(s.groupby("Subject"+str(n))["Mark"+str(n)].sum())
                                elif o==5:
                                    print(s.groupby("Subject"+str(n))["Mark"+str(n)].mean())
                                elif o==6:
                                    break
                                else:
                                    print("Invalid input")
                                    
                        elif m==3:
                            break
                        else:
                            print("Invalid input")
                            
                elif Q=="Exit":
                    break
                else:
                    print("Invalid input")
            elif b==2:
                n=int(input("""Which subject would you like to analyse:
                        1. Subject 1
                        2. Subject 2
                        3. Subject 3
                        4. Subject 4
                        5. Subject 5
                        6. Exit
                        """))
                if n==6:
                    break
                elif n>6:
                    print("Invalid Input")
                    continue
                while n:
                    m=int(input("""Do you want to analyse:
                                    1. Grade wise
                                    2. Mark wise
                                    3. Exit
                                    """))
                    if m==1:
                        print(df.groupby("Grade"+str(n))["Grade"+str(n)].count())
                    elif m==2:
                        while True: 
                            o=int(input("""Would you like to: 
                                    1. Count the number of students with unique data
                                    2. Minimum marks
                                    3. Maximum marks
                                    4. Total
                                    5. Average
                                    6. Exit 
                                    """))   
                            if o==1:
                                print(df.groupby("Mark"+str(n))["Mark"+str(n)].count())
                            elif o==2:
                                print(df.groupby("Subject"+str(n))["Mark"+str(n)].min())
                            elif o==3:
                                print(df.groupby("Subject"+str(n))["Mark"+str(n)].max())
                            elif o==4:
                                print(df.groupby("Subject"+str(n))["Mark"+str(n)].sum())
                            elif o==5:
                                print(df.groupby("Subject"+str(n))["Mark"+str(n)].mean())
                            elif o==6:
                                break
                            else:
                                print("Invalid input")                            
                    elif m==3:
                        break
                    else:
                        print("Invalid input")
            else:
                break
    elif a==2:
        while True:
            h=int(input("""Would you like to visualise data as
            1. Line graph
            2. Bar graph
            3. Exit
            """))
            if h==1:
                while True:
                    s=int(input("""Would you like to analyse subject-wise comparison of
                1. minimum marks
                2. maximum marks
                3. total marks
                4. average marks
                5. exit
                """))
                    if s==1:
                        a=df.Mark1.min()
                        b=df.Mark2.min()
                        c=df.Mark3.min()
                        d=df.Mark4.min()
                        e=df.Mark5.min()
                        h=[a,b,c,d,e]
                        f=[0,1,2,3,4]
                        labels=["Subject1","Subject2","Subject3","Subject4","Subject5"]
                        plt.plot(h,label="Minimum marks")
                        plt.xticks(f,labels,rotation="vertical")
                        plt.xlabel("Subject")
                        plt.ylabel("Marks")
                        plt.legend()
                        plt.show()
                    elif s==2:
                        a=df.Mark1.max()
                        b=df.Mark2.max()
                        c=df.Mark3.max()
                        d=df.Mark4.max()
                        e=df.Mark5.max()
                        h=[a,b,c,d,e]
                        f=[0,1,2,3,4]
                        labels=["Subject1","Subject2","Subject3","Subject4","Subject5"]
                        plt.plot(h,label="Maximum marks")
                        plt.xticks(f,labels,rotation="vertical")
                        plt.xlabel("Subject")
                        plt.ylabel("Marks")
                        plt.legend()
                        plt.show()
                    elif s==3:
                        a=df.Mark1.sum()
                        b=df.Mark2.sum()
                        c=df.Mark3.sum()
                        d=df.Mark4.sum()
                        e=df.Mark5.sum()
                        h=[a,b,c,d,e]
                        f=[0,1,2,3,4]
                        labels=["Subject1","Subject2","Subject3","Subject4","Subject5"]
                        plt.plot(h,label="Total marks")
                        plt.xticks(f,labels,rotation="vertical")
                        plt.xlabel("Subject")
                        plt.ylabel("Marks")
                        plt.legend()
                        plt.show()
                    elif s==4:
                        a=df.Mark1.mean()
                        b=df.Mark2.mean()
                        c=df.Mark3.mean()
                        d=df.Mark4.mean()
                        e=df.Mark5.mean()
                        h=[a,b,c,d,e]
                        f=[0,1,2,3,4]
                        labels=["Subject1","Subject2","Subject3","Subject4","Subject5"]
                        plt.plot(h,label="Average marks")
                        plt.xticks(f,labels,rotation="vertical")
                        plt.xlabel("Subject")
                        plt.ylabel("Marks")
                        plt.legend()
                        plt.show()
                    elif s==5:
                        break
                    else:
                        print("Invalid Input")
            elif h==2:
                while True:
                    s=int(input("""Would you like to analyse subject-wise comparison of
                1. minimum marks
                2. maximum marks
                3. total marks
                4. average marks
                5. exit
                """))
                    if s==1:
                        a=df.Mark1.min()
                        b=df.Mark2.min()
                        c=df.Mark3.min()
                        d=df.Mark4.min()
                        e=df.Mark5.min()
                        x=0
                        f=[0,0.5,1,1.5,2]
                        labels=["Subject1","Subject2","Subject3","Subject4","Subject5"]
                        plt.bar(x,a,color=["g"],width=0.25,edgecolor="k",label=["Subject1"])
                        plt.bar(x+0.5,b,color=["y"],width=0.25,edgecolor="k",label=["Subject2"])
                        plt.bar(x+1,c,color=["r"],width=0.25,edgecolor="k",label=["Subject3"])
                        plt.bar(x+1.5,d,color=["m"],width=0.25,edgecolor="k",label=["Subject4"])
                        plt.bar(x+2,b,color=["k"],width=0.25,edgecolor="k",label=["Subject5"])
                        plt.ylim(70,100)
                        plt.xticks(f,labels,rotation="vertical")
                        plt.title("Minimum Marks")
                        plt.xlabel("Subject")
                        plt.ylabel("Marks")
                        plt.legend()
                        plt.figure(figsize=(20,20))
                        plt.show()

                    elif s==2:
                        a=df.Mark1.max()
                        b=df.Mark2.max()
                        c=df.Mark3.max()
                        d=df.Mark4.max()
                        e=df.Mark5.max()
                        x=0
                        f=[0,0.5,1,1.5,2]
                        labels=["Subject1","Subject2","Subject3","Subject4","Subject5"]
                        plt.bar(x,a,color=["g"],width=0.25,edgecolor="k",label=["Subject1"])
                        plt.bar(x+0.5,b,color=["y"],width=0.25,edgecolor="k",label=["Subject2"])
                        plt.bar(x+1,c,color=["r"],width=0.25,edgecolor="k",label=["Subject3"])
                        plt.bar(x+1.5,d,color=["m"],width=0.25,edgecolor="k",label=["Subject4"])
                        plt.bar(x+2,b,color=["k"],width=0.25,edgecolor="k",label=["Subject5"])
                        plt.xticks(f,labels,rotation="vertical")
                        plt.ylim(95,100)
                        plt.title("Maximum Marks")
                        plt.xlabel("Subject")
                        plt.ylabel("Marks")
                        plt.legend(loc="lower right")
                        plt.figure(figsize=(20,20))
                        plt.show()
                    elif s==3:
                        a=df.Mark1.sum()
                        b=df.Mark2.sum()
                        c=df.Mark3.sum()
                        d=df.Mark4.sum()
                        e=df.Mark5.sum()
                        x=0
                        f=[0,0.5,1,1.5,2]
                        labels=["Subject1","Subject2","Subject3","Subject4","Subject5"]
                        plt.bar(x,a,color=["g"],width=0.25,edgecolor="k",label=["Subject1"])
                        plt.bar(x+0.5,b,color=["y"],width=0.25,edgecolor="k",label=["Subject2"])
                        plt.bar(x+1,c,color=["r"],width=0.25,edgecolor="k",label=["Subject3"])
                        plt.bar(x+1.5,d,color=["m"],width=0.25,edgecolor="k",label=["Subject4"])
                        plt.bar(x+2,b,color=["k"],width=0.25,edgecolor="k",label=["Subject5"])
                        plt.xticks(f,labels,rotation="vertical")
                        plt.ylim(2300,2800)
                        plt.title("Total Marks")
                        plt.xlabel("Subject")
                        plt.ylabel("Marks")
                        plt.legend()
                        plt.figure(figsize=(100,100))
                        plt.show()
                    elif s==4:
                        a=df.Mark1.mean()
                        b=df.Mark2.mean()
                        c=df.Mark3.mean()
                        d=df.Mark4.mean()
                        e=df.Mark5.mean()
                        x=0
                        f=[0,0.5,1,1.5,2]
                        labels=["Subject1","Subject2","Subject3","Subject4","Subject5"]
                        plt.bar(x,a,color=["g"],width=0.25,edgecolor="k",label=["Subject1"])
                        plt.bar(x+0.5,b,color=["y"],width=0.25,edgecolor="k",label=["Subject2"])
                        plt.bar(x+1,c,color=["r"],width=0.25,edgecolor="k",label=["Subject3"])
                        plt.bar(x+1.5,d,color=["m"],width=0.25,edgecolor="k",label=["Subject4"])
                        plt.bar(x+2,b,color=["k"],width=0.25,edgecolor="k",label=["Subject5"])
                        plt.xticks(f,labels,rotation="vertical")
                        plt.ylim(80,100)
                        plt.title("Average Marks")
                        plt.xlabel("Subject")
                        plt.ylabel("Marks")
                        plt.legend()
                        plt.figure(figsize=(20,20))
                        plt.show()
                    elif s==5:
                        break
                    else:
                        print("invalid input")
            elif h==3:
                break
            else:
                print("Invalid Input")
    elif a==3:
        print("""
Exitting
        
Closed""")
        print("*"*100)
        break
    else:
        print("Invalid input")
# Out:
# Do you want to
#     1. Analyze the data
#     2. Visualise the data
#     3. Exit
#     2
# Would you like to visualise data as
#             1. Line graph
#             2. Bar graph
#             3. Exit
#             1
# Would you like to analyse subject-wise comparison of
#                 1. minimum marks
#                 2. maximum marks
#                 3. total marks
#                 4. average marks
#                 5. exit
#                 2
# Would you like to analyse subject-wise comparison of
#                 1. minimum marks
#                 2. maximum marks
#                 3. total marks
#                 4. average marks
#                 5. exit
#                 5
# Would you like to visualise data as
#             1. Line graph
#             2. Bar graph
#             3. Exit
#             2
# Would you like to analyse subject-wise comparison of
#                 1. minimum marks
#                 2. maximum marks
#                 3. total marks
# ...
